# %%
# Data Cleaning and Preprocessing

## Objective
To clean and preprocess the Iris dataset provided by Codveda Technology.

# %%
pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 152.4 kB/s  0:00:58157.6 kB/s eta 0:00:02
# ...
#    ━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/5.2 MB 114.3 kB/s eta 0:00:41
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (524 kB/5.2 MB, attempt 1)
# Resuming download numpy-2.4.1-cp314-cp314-macosx_14_0_arm64.whl (524 kB/5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2.6/5.2 MB 28.8 kB/s eta 0:01:30m
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (2.6 MB/5.2 MB, attempt 2)
# Resuming download numpy-2.4.1-cp314-cp314-macosx_14_0_arm64.whl (2.6 MB/5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3.9/5.2 MB 95.7 kB/s eta 0:00:14m
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (3.9 MB/5.2 MB, attempt 3)
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("raw_dataset.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# ...

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# No missing values were found in the dataset.

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
pip install scikit-learn
# Out:
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 162.2 kB/s  0:00:45160.2 kB/s eta 0:00:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 171.2 kB/s  0:01:41 eta 0:00:020:00:05
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn]0m 3/4 [scikit-learn]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
df = pd.read_csv("raw_dataset.csv")
le = LabelEncoder()
df['species'] = le.fit_transform(df['species'])

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler

df = pd.read_csv("raw_dataset.csv")

# Encode categorical column
le = LabelEncoder()
df['species'] = le.fit_transform(df['species'])

# Scale numerical features
scaler = StandardScaler()
numeric_cols = df.select_dtypes(include=np.number).columns
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width   species
# 0     -0.900681     1.032057     -1.341272    -1.312977 -1.224745
# 1     -1.143017    -0.124958     -1.341272    -1.312977 -1.224745
# 2     -1.385353     0.337848     -1.398138    -1.312977 -1.224745
# 3     -1.506521     0.106445     -1.284407    -1.312977 -1.224745
# 4     -1.021849     1.263460     -1.341272    -1.312977 -1.224745

# %% [markdown]
# The target column 'species' contained categorical values, which were converted into numerical form using Label Encoding.
# Feature scaling was applied only to numerical columns using StandardScaler.

# %%
df.to_csv("cleaned_dataset.csv", index=False)
